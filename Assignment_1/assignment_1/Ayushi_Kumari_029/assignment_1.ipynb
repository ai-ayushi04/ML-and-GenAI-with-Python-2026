# %%
#area of rectangle
l=float(input("enter length"))
b=float(input("enter breadth"))
print("Area of rectangle having length =",l,"and breadth=",b,"is",l*b)
# Out:
# enter length10.5
# enter breadth3.4
# Area of rectangle having length = 10.5 and breadth= 3.4 is 35.699999999999996

# %%
principal = float(input("Enter principal: "))
rate = float(input("Enter rate of interest: "))
time = float(input("Enter time (years): "))
si = (principal * rate * time) / 100
print("Simple Interest:", si)
# Out:
# Enter principal: 10000
# Enter rate of interest: 4
# Enter time (years): 3
# Simple Interest: 1200.0

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 48
# Temperature in Fahrenheit: 118.4

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
average = (a + b + c) / 3
print("Average:", average)
# Out:
# Enter first number: 24
# Enter second number: 35
# Enter third number: 65
# Average: 41.333333333333336

# %%
num = float(input("Enter a number: "))
print("Square:", num ** 2)
print("Cube:", num ** 3)
# Out:
# Enter a number: 4
# Square: 16.0
# Cube: 64.0

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
a, b = b, a
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 35
# Enter second number: 64
# After swapping:
# a = 64.0
# b = 35.0

# %%
name = input("Enter student name: ")
roll = input("Enter roll number: ")
m1 = float(input("Enter marks of subject 1: "))
m2 = float(input("Enter marks of subject 2: "))
m3 = float(input("Enter marks of subject 3: "))
total = m1 + m2 + m3
percentage = (total / 300) * 100
print("\n----- Student Report -----")
print("Name:", name)
print("Roll No:", roll)
print("Total Marks:", total)
print("Percentage:", percentage)
# Out:
# Enter student name: abc
# Enter roll number: 1
# Enter marks of subject 1: 89
# Enter marks of subject 2: 79
# Enter marks of subject 3: 90
#
# ----- Student Report -----
# Name: abc
# Roll No: 1
# Total Marks: 258.0
# Percentage: 86.0
